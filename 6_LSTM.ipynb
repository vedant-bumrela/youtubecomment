# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# Create simple time series data
data = np.sin(np.arange(1000))  # sine wave

# Prepare sequences
X, y = [], []
for i in range(len(data) - 10):
    X.append(data[i:i+10])
    y.append(data[i+10])

X = np.array(X)
y = np.array(y)
X = X.reshape((X.shape[0], X.shape[1], 1))

# Build LSTM model
model = Sequential([
    LSTM(50, input_shape=(10, 1)),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=5)
predict = model.predict(X)

plt.figure(figsize=(10, 5))
plt.plot(y, label='Actual')
plt.plot(predict, label='Predicted')
plt.title("Time Series Forecasting with LSTM")  
plt.legend()
plt.show()
# Out:
# Epoch 1/5
# c:\Users\vedan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4505
# Epoch 2/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1100
# Epoch 3/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0255
# Epoch 4/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048
# Epoch 5/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7062e-04
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
